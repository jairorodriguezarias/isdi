# %% [markdown]
# 1. Descargar datos de https://github.com/jairorodriguezarias/isdi.git
# 2. Descomprimir datos.
#   - CUSTOMER.csv
#   - LINEITEM.csv
#   - NATION.csv
#   - ORDERS.csv
#   - REGION.csv
#   - SUPPLIER.csv
#
# 3. Subir datos usando funcionalidad "UPLOAD DATA"
#   - dbfs:/FileStore/shop/LINEITEM.csv
#   - dbfs:/FileStore/shop/NATION.csv
#   - dbfs:/FileStore/shop/ORDERS.csv
#   - dbfs:/FileStore/shop/README.md
#   - dbfs:/FileStore/shop/REGION.csv
#   - dbfs:/FileStore/shop/SUPPLIER.csv

# %%
# %sql
CREATE DATABASE IF NOT EXISTS isdi;
USE isdi;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Subir datos desde barra lateral DATOS -> CREATE NEW TABLE -> UPLOAD
#
# File UPLOAD  **/FileStore/tables/data_centers_q2_q3_snappy_parquet.zip**
